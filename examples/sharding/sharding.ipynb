# %% [markdown]
# ## **Installation**
# Requirements:
# - python >= 3.7
#
# We highly recommend CUDA when using torchRec. If using CUDA:
# - cuda >= 11.0

# %%
# install conda to make installying pytorch with cudatoolkit 11.3 easier. 
# !sudo rm Miniconda3-py37_4.9.2-Linux-x86_64.sh Miniconda3-py37_4.9.2-Linux-x86_64.sh.*
# !sudo wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# !sudo chmod +x Miniconda3-py37_4.9.2-Linux-x86_64.sh
# !sudo bash ./Miniconda3-py37_4.9.2-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# rm: cannot remove 'Miniconda3-py37_4.9.2-Linux-x86_64.sh.*': No such file or directory
# --2022-04-18 20:38:22--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90040905 (86M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.9 100%[===================>]  85.87M  88.1MB/s    in 1.0s
#
# 2022-04-18 20:38:23 (88.1 MB/s) - ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh’ saved [90040905/90040905]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package ld_impl_linux-64 conflicts for:
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# python==3.7.9=h7579374_0 -> ld_impl_linux-64
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> ld_impl_linux-64
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> ld_impl_linux-64
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> ld_impl_linux-64
# requests==2.24.0=py_0 -> python -> ld_impl_linux-64
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# idna==2.10=py_0 -> python -> ld_impl_linux-64
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pycparser==2.20=py_2 -> python -> ld_impl_linux-64
# typing_extensions -> python[version='>=3.6'] -> ld_impl_linux-64
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# ld_impl_linux-64==2.33.1=h53a641e_7
#
# Package xz conflicts for:
# idna==2.10=py_0 -> python -> xz[version='>=5.2.5,<6.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# python==3.7.9=h7579374_0 -> xz[version='>=5.2.5,<6.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> xz[version='>=5.2.5,<6.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> xz[version='>=5.2.5,<6.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> xz[version='>=5.2.5,<6.0a0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# typing_extensions -> python[version='>=3.6'] -> xz[version='>=5.2.5,<6.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> xz[version='>=5.2.5,<6.0a0']
# xz==5.2.5=h7b6447c_0
# requests==2.24.0=py_0 -> python -> xz[version='>=5.2.5,<6.0a0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> xz[version='>=5.2.5,<6.0a0']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pycparser==2.20=py_2 -> python -> xz[version='>=5.2.5,<6.0a0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
#
# Package python conflicts for:
# setuptools==50.3.1=py37h06a4308_1 -> certifi[version='>=2016.9.26'] -> python
# pycparser==2.20=py_2 -> python
# python==3.7.9=h7579374_0
# pytorch -> typing_extensions -> python[version='>=3.6']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> tqdm -> python
# conda==4.9.2=py37h06a4308_0 -> pyopenssl[version='>=16.2.0'] -> python
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0']
# requests==2.24.0=py_0 -> certifi[version='>=2017.4.17'] -> python[version='<4.0|>=3.7,<3.8.0a0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0']
# pytorch -> python[version='>=3.7,<3.8.0a0']
# typing_extensions -> python[version='>=3.6']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python
# wheel==0.35.1=pyhd3eb1b0_0 -> python
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0']
# pip==20.2.4=py37h06a4308_0 -> wheel -> python
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0']
# requests==2.24.0=py_0 -> python
# certifi==2020.6.20=pyhd3eb1b0_3 -> python
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0']
# cffi==1.14.3=py37h261ae71_2 -> pycparser -> python
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0'] -> python[version='>=3.7,<3.8.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> python[version='>=3.7,<3.8.0a0']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0']
# idna==2.10=py_0 -> python
# urllib3==1.25.11=py_0 -> python[version='<4.0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0']
#
# Package libgcc-ng conflicts for:
# pytorch -> cudatoolkit[version='>=11.3,<11.4'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# pycparser==2.20=py_2 -> python -> libgcc-ng[version='>=7.3.0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> libgcc-ng[version='>=7.3.0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> libgcc-ng[version='>=7.3.0']
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0'] -> libgcc-ng[version='>=7.3.0']
# libgcc-ng==9.1.0=hdf63c60_0
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> libgcc-ng[version='>=7.3.0']
# cffi==1.14.3=py37h261ae71_2 -> libgcc-ng[version='>=7.3.0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> libgcc-ng[version='>=7.3.0']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0']
# sqlite==3.33.0=h62c20be_0 -> libgcc-ng[version='>=7.3.0']
# libuv -> libgcc-ng[version='>=7.3.0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> libgcc-ng[version='>=7.3.0']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# cryptography==3.2.1=py37h3c74f83_1 -> openssl[version='>=1.1.1h,<1.1.2a'] -> libgcc-ng[version='>=7.5.0']
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# idna==2.10=py_0 -> python -> libgcc-ng[version='>=7.3.0']
# pycosat==0.6.3=py37h27cfd23_0 -> libgcc-ng[version='>=7.3.0']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# python==3.7.9=h7579374_0 -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=7.5.0']
# cryptography==3.2.1=py37h3c74f83_1 -> libgcc-ng[version='>=7.3.0']
# cudatoolkit -> libgcc-ng[version='>=9.3.0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> libgcc-ng[version='>=7.3.0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> libgcc-ng[version='>=7.3.0']
# conda==4.9.2=py37h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> libgcc-ng[version='>=7.3.0']
# python==3.7.9=h7579374_0 -> libgcc-ng[version='>=7.3.0']
# libedit==3.1.20191231=h14c3975_1 -> libgcc-ng[version='>=7.3.0']
# yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# requests==2.24.0=py_0 -> python -> libgcc-ng[version='>=7.3.0']
# openssl==1.1.1h=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# typing_extensions -> python[version='>=3.6'] -> libgcc-ng[version='>=7.3.0']
#
# Package zlib conflicts for:
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# idna==2.10=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlite==3.33.0=h62c20be_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# zlib==1.2.11=h7b6447c_3
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python==3.7.9=h7579374_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# requests==2.24.0=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# typing_extensions -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pycparser==2.20=py_2 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
#
# Package openssl conflicts for:
# requests==2.24.0=py_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pycparser==2.20=py_2 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# openssl==1.1.1h=h7b6447c_0
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# cryptography==3.2.1=py37h3c74f83_1 -> openssl[version='>=1.1.1h,<1.1.2a']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# urllib3==1.25.11=py_0 -> cryptography[version='>=1.3.4'] -> openssl[version='>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> openssl[version='>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a']
# python==3.7.9=h7579374_0 -> openssl[version='>=1.1.1g,<1.1.2a']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# typing_extensions -> python[version='>=3.6'] -> openssl[version='>=1.1.1g,<1.1.2a']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# idna==2.10=py_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
#
# Package libffi conflicts for:
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> libffi[version='>=3.3,<3.4.0a0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> libffi[version='>=3.3,<3.4.0a0']
# libffi==3.3=he6710b0_2
# cffi==1.14.3=py37h261ae71_2 -> libffi[version='>=3.3,<3.4.0a0']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> cffi[version='>=1.0.0'] -> libffi[version='>=3.3,<3.4.0a0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# idna==2.10=py_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> libffi[version='>=3.3,<3.4.0a0']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# python==3.7.9=h7579374_0 -> libffi[version='>=3.3,<3.4.0a0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# typing_extensions -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# requests==2.24.0=py_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# cryptography==3.2.1=py37h3c74f83_1 -> cffi[version='!=1.11.3,>=1.8'] -> libffi[version='>=3.3,<3.4.0a0']
# pycparser==2.20=py_2 -> python -> libffi[version='>=3.3,<3.4.0a0']
#
# Package _openmp_mutex conflicts for:
# conda-package-handling==1.7.2=py37h03888b9_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pycosat==0.6.3=py37h27cfd23_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# python==3.7.9=h7579374_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# _openmp_mutex
# libedit==3.1.20191231=h14c3975_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# brotlipy==0.7.0=py37h27cfd23_1003 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# cffi==1.14.3=py37h261ae71_2 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# cudatoolkit -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# sqlite==3.33.0=h62c20be_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# openssl==1.1.1h=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# cryptography==3.2.1=py37h3c74f83_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libuv -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
#
# Package _libgcc_mutex conflicts for:
# libedit==3.1.20191231=h14c3975_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# pycosat==0.6.3=py37h27cfd23_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libgcc-ng==9.1.0=hdf63c60_0 -> _libgcc_mutex=[build=main]
# _openmp_mutex -> _libgcc_mutex==0.1=main
# _libgcc_mutex==0.1=main
# libgomp -> _libgcc_mutex==0.1=main
# brotlipy==0.7.0=py37h27cfd23_1003 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# cudatoolkit -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# cffi==1.14.3=py37h261ae71_2 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# sqlite==3.33.0=h62c20be_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# conda-package-handling==1.7.2=py37h03888b9_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libuv -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# cryptography==3.2.1=py37h3c74f83_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# python==3.7.9=h7579374_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# openssl==1.1.1h=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
#
# Package ncurses conflicts for:
# python==3.7.9=h7579374_0 -> ncurses[version='>=6.2,<7.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> ncurses[version='>=6.2,<7.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> ncurses[version='>=6.2,<7.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# requests==2.24.0=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pycparser==2.20=py_2 -> python -> ncurses[version='>=6.2,<7.0a0']
# typing_extensions -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# sqlite==3.33.0=h62c20be_0 -> ncurses[version='>=6.2,<7.0a0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# libedit==3.1.20191231=h14c3975_1 -> ncurses[version='>=6.2,<7.0a0']
# idna==2.10=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> ncurses[version='>=6.2,<7.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python==3.7.9=h7579374_0 -> readline[version='>=8.0,<9.0a0'] -> ncurses[version='>=6.1,<7.0a0']
# ncurses==6.2=he6710b0_1
#
# Package yaml conflicts for:
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> yaml[version='>=0.2.5,<0.3.0a0']
# yaml==0.2.5=h7b6447c_0
# conda==4.9.2=py37h06a4308_0 -> ruamel_yaml[version='>=0.11.14,<0.16'] -> yaml[version='>=0.2.5,<0.3.0a0']
#
# Package ca-certificates conflicts for:
# cryptography==3.2.1=py37h3c74f83_1 -> openssl[version='>=1.1.1h,<1.1.2a'] -> ca-certificates
# openssl==1.1.1h=h7b6447c_0 -> ca-certificates
# ca-certificates==2020.10.14=0
# python==3.7.9=h7579374_0 -> openssl[version='>=1.1.1g,<1.1.2a'] -> ca-certificates
#
# Package libgomp conflicts for:
# libgomp
# _openmp_mutex -> libgomp[version='>=7.5.0']
#
# Package setuptools conflicts for:
# pip==20.2.4=py37h06a4308_0 -> setuptools
# conda==4.9.2=py37h06a4308_0 -> setuptools[version='>=31.0.1']
# setuptools==50.3.1=py37h06a4308_1
#
# Package chardet conflicts for:
# requests==2.24.0=py_0 -> chardet[version='>=3.0.2,<4']
# conda==4.9.2=py37h06a4308_0 -> requests[version='>=2.18.4,<3'] -> chardet[version='>=3.0.2,<4']
# chardet==3.0.4=py37h06a4308_1003
#
# Package certifi conflicts for:
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> certifi
# urllib3==1.25.11=py_0 -> certifi
# requests==2.24.0=py_0 -> certifi[version='>=2017.4.17']
# certifi==2020.6.20=pyhd3eb1b0_3
# setuptools==50.3.1=py37h06a4308_1 -> certifi[version='>=2016.9.26']
# pip==20.2.4=py37h06a4308_0 -> setuptools -> certifi[version='>=2016.9.26']
# conda==4.9.2=py37h06a4308_0 -> requests[version='>=2.18.4,<3'] -> certifi[version='>=2016.9.26|>=2017.4.17']
#
# Package tk conflicts for:
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# python==3.7.9=h7579374_0 -> tk[version='>=8.6.10,<8.7.0a0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> tk[version='>=8.6.10,<8.7.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> tk[version='>=8.6.10,<8.7.0a0']
# requests==2.24.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0']
# idna==2.10=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> tk[version='>=8.6.10,<8.7.0a0']
# tk==8.6.10=hbc83047_0
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# pycparser==2.20=py_2 -> python -> tk[version='>=8.6.10,<8.7.0a0']
# typing_extensions -> python[version='>=3.6'] -> tk[version='>=8.6.10,<8.7.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> tk[version='>=8.6.10,<8.7.0a0']
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> tk[version='>=8.6.10,<8.7.0a0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0']
#
# Package six conflicts for:
# conda==4.9.2=py37h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> six[version='>=1.5.2']
# cryptography==3.2.1=py37h3c74f83_1 -> six[version='>=1.4.1']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> six[version='>=1.5.2']
# urllib3==1.25.11=py_0 -> cryptography[version='>=1.3.4'] -> six[version='>=1.4.1|>=1.5.2']
# six==1.15.0=py37h06a4308_0
# conda-package-handling==1.7.2=py37h03888b9_0 -> six
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> six[version='>=1.4.1']
#
# Package conda-package-handling conflicts for:
# conda-package-handling==1.7.2=py37h03888b9_0
# conda==4.9.2=py37h06a4308_0 -> conda-package-handling[version='>=1.3.0']
#
# Package pyopenssl conflicts for:
# urllib3==1.25.11=py_0 -> pyopenssl[version='>=0.14']
# conda==4.9.2=py37h06a4308_0 -> pyopenssl[version='>=16.2.0']
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pyopenssl[version='>=0.14']
# pyopenssl==19.1.0=pyhd3eb1b0_1
#
# Package cudatoolkit conflicts for:
# pytorch -> cudatoolkit[version='>=11.3,<11.4']
# cudatoolkit
#
# Package sqlite conflicts for:
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> sqlite[version='>=3.33.0,<4.0a0']
# idna==2.10=py_0 -> python -> sqlite[version='>=3.33.0,<4.0a0']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# python==3.7.9=h7579374_0 -> sqlite[version='>=3.33.0,<4.0a0']
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> sqlite[version='>=3.33.0,<4.0a0']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# requests==2.24.0=py_0 -> python -> sqlite[version='>=3.33.0,<4.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> sqlite[version='>=3.33.0,<4.0a0']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# typing_extensions -> python[version='>=3.6'] -> sqlite[version='>=3.33.0,<4.0a0']
# pycparser==2.20=py_2 -> python -> sqlite[version='>=3.33.0,<4.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> sqlite[version='>=3.33.0,<4.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> sqlite[version='>=3.33.0,<4.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.33.0,<4.0a0']
# sqlite==3.33.0=h62c20be_0
#
# Package cryptography conflicts for:
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8']
# urllib3==1.25.11=py_0 -> cryptography[version='>=1.3.4']
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> cryptography[version='>=1.3.4']
# urllib3==1.25.11=py_0 -> pyopenssl[version='>=0.14'] -> cryptography[version='>=2.8']
# cryptography==3.2.1=py37h3c74f83_1
# conda==4.9.2=py37h06a4308_0 -> pyopenssl[version='>=16.2.0'] -> cryptography[version='>=2.8']
#
# Package intel-openmp conflicts for:
# intel-openmp
# pytorch -> mkl[version='>=2018'] -> intel-openmp=2022
# mkl -> intel-openmp=2022
#
# Package readline conflicts for:
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> readline[version='>=8.0,<9.0a0']
# six==1.15.0=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# setuptools==50.3.1=py37h06a4308_1 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# conda-package-handling==1.7.2=py37h03888b9_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# python==3.7.9=h7579374_0 -> readline[version='>=8.0,<9.0a0']
# conda==4.9.2=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# idna==2.10=py_0 -> python -> readline[version='>=8.0,<9.0a0']
# pysocks==1.7.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pip==20.2.4=py37h06a4308_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# cryptography==3.2.1=py37h3c74f83_1 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# typing_extensions -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# chardet==3.0.4=py37h06a4308_1003 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycosat==0.6.3=py37h27cfd23_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> readline[version='>=8.0,<9.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> readline[version='>=8.0,<9.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> readline[version='>=8.0,<9.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_1 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pytorch -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# requests==2.24.0=py_0 -> python -> readline[version='>=8.0,<9.0a0']
# readline==8.0=h7b6447c_0
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> readline[version='>=8.0,<9.0a0']
# brotlipy==0.7.0=py37h27cfd23_1003 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycparser==2.20=py_2 -> python -> readline[version='>=8.0,<9.0a0']
# cffi==1.14.3=py37h261ae71_2 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
#
# Package pycparser conflicts for:
# pycparser==2.20=py_2
# cryptography==3.2.1=py37h3c74f83_1 -> cffi[version='!=1.11.3,>=1.8'] -> pycparser
# cffi==1.14.3=py37h261ae71_2 -> pycparser
# brotlipy==0.7.0=py37h27cfd23_1003 -> cffi[version='>=1.0.0'] -> pycparser
#
# Package typing_extensions conflicts for:
# typing_extensions
# pytorch -> typing_extensions
#
# Package pycosat conflicts for:
# pycosat==0.6.3=py37h27cfd23_0
# conda==4.9.2=py37h06a4308_0 -> pycosat[version='>=0.6.3']
#
# Package libstdcxx-ng conflicts for:
# cffi==1.14.3=py37h261ae71_2 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libstdcxx-ng==9.1.0=hdf63c60_0
# cudatoolkit -> libstdcxx-ng[version='>=9.3.0']
# ncurses==6.2=he6710b0_1 -> libstdcxx-ng[version='>=7.3.0']
# pytorch -> cudatoolkit[version='>=11.3,<11.4'] -> libstdcxx-ng[version='>=9.3.0']
# libedit==3.1.20191231=h14c3975_1 -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libffi==3.3=he6710b0_2 -> libstdcxx-ng[version='>=7.3.0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# sqlite==3.33.0=h62c20be_0 -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# python==3.7.9=h7579374_0 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
#
# Package brotlipy conflicts for:
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0']
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> brotlipy[version='>=0.6.0']
# brotlipy==0.7.0=py37h27cfd23_1003
#
# Package libuv conflicts for:
# pytorch -> libuv[version='>=1.40.0,<2.0a0']
# libuv
#
# Package urllib3 conflicts for:
# conda==4.9.2=py37h06a4308_0 -> requests[version='>=2.18.4,<3'] -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1']
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1']
# urllib3==1.25.11=py_0
#
# Package idna conflicts for:
# urllib3==1.25.11=py_0 -> idna[version='>=2.0.0']
# conda==4.9.2=py37h06a4308_0 -> requests[version='>=2.18.4,<3'] -> idna[version='>=2.5,<3']
# idna==2.10=py_0
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> idna[version='>=2.0.0']
# requests==2.24.0=py_0 -> idna[version='>=2.5,<3']
#
# Package pysocks conflicts for:
# pysocks==1.7.1=py37_1
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# urllib3==1.25.11=py_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package requests conflicts for:
# requests==2.24.0=py_0
# conda==4.9.2=py37h06a4308_0 -> requests[version='>=2.18.4,<3']
#
# Package libedit conflicts for:
# python==3.7.9=h7579374_0 -> sqlite[version='>=3.33.0,<4.0a0'] -> libedit[version='>=3.1.20191231,<3.2.0a0']
# sqlite==3.33.0=h62c20be_0 -> libedit[version='>=3.1.20191231,<3.2.0a0']
# libedit==3.1.20191231=h14c3975_1
#
# Package cffi conflicts for:
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> cffi[version='!=1.11.3,>=1.8']
# cryptography==3.2.1=py37h3c74f83_1 -> cffi[version='!=1.11.3,>=1.8']
# cffi==1.14.3=py37h261ae71_2
# brotlipy==0.7.0=py37h27cfd23_1003 -> cffi[version='>=1.0.0']
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0'] -> cffi[version='!=1.11.3,>=1.8|>=1.0.0']
#
# Package mkl conflicts for:
# pytorch -> mkl[version='>=2018']
# mkl
#
# Package tqdm conflicts for:
# conda-package-handling==1.7.2=py37h03888b9_0 -> tqdm
# tqdm==4.51.0=pyhd3eb1b0_0
# conda==4.9.2=py37h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> tqdm
#
# Package wheel conflicts for:
# wheel==0.35.1=pyhd3eb1b0_0
# pip==20.2.4=py37h06a4308_0 -> wheel
#
# Package pytorch-mutex conflicts for:
# pytorch -> pytorch-mutex==1.0=cuda
# pytorch-mutex
#
# Package blas conflicts for:
# pytorch -> blas=[build=mkl]
# blas
#
# Package ruamel_yaml conflicts for:
# ruamel_yaml==0.15.87=py37h7b6447c_1
# conda==4.9.2=py37h06a4308_0 -> ruamel_yaml[version='>=0.11.14,<0.16']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.27=0
#   - feature:|@/linux-64::__glibc==2.27=0
#   - brotlipy==0.7.0=py37h27cfd23_1003 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cffi==1.14.3=py37h261ae71_2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - conda-package-handling==1.7.2=py37h03888b9_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cryptography==3.2.1=py37h3c74f83_1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cudatoolkit -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libedit==3.1.20191231=h14c3975_1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libuv -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - openssl==1.1.1h=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pycosat==0.6.3=py37h27cfd23_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - python==3.7.9=h7579374_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - ruamel_yaml==0.15.87=py37h7b6447c_1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - sqlite==3.33.0=h62c20be_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.27

# %%
# install pytorch with cudatoolkit 11.3
# !sudo conda install pytorch cudatoolkit=11.3 -c pytorch-nightly -y
# Out:
# done
# done
#
# # All requested packages already installed.

# %% [markdown]
# Installing torchRec will also install [FBGEMM](https://github.com/pytorch/fbgemm), a collection of CUDA kernels and GPU enabled operations to run

# %%
# install torchrec
# !pip3 install torchrec-nightly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchrec-nightly in ./.local/lib/python3.7/site-packages (2022.4.17)
# Requirement already satisfied: sortedcontainers in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2.4.0)
# Requirement already satisfied: python-dateutil in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2.8.2)
# Requirement already satisfied: iopath in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.1.9)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from torchrec-nightly) (2.18.4)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from torchrec-nightly) (2018.1.18)
# Requirement already satisfied: fsspec in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2022.3.0)
# Requirement already satisfied: pyDeprecate in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.3.2)
# Requirement already satisfied: torchx-nightly in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2022.4.18)
# Requirement already satisfied: pandas in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (1.3.5)
# Requirement already satisfied: Jinja2 in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (3.1.1)
# Requirement already satisfied: filelock in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (3.6.0)
# Requirement already satisfied: cmake in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (3.22.4)
# Requirement already satisfied: tqdm in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (4.64.0)
# Requirement already satisfied: pytz in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2022.1)
# Requirement already satisfied: ninja in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (1.10.2.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from torchrec-nightly) (1.11.0)
# Requirement already satisfied: PyYAML in /usr/lib/python3/dist-packages (from torchrec-nightly) (3.12)
# Requirement already satisfied: portalocker in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2.4.0)
# Requirement already satisfied: pyparsing in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (3.0.8)
# Requirement already satisfied: MarkupSafe in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2.1.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from torchrec-nightly) (0.29.26)
# Requirement already satisfied: tabulate in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.8.9)
# Requirement already satisfied: typing-inspect in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.7.1)
# Requirement already satisfied: typing-extensions in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (4.1.1)
# Requirement already satisfied: hypothesis in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (6.43.3)
# Requirement already satisfied: pyre-extensions in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.0.27)
# Requirement already satisfied: websocket-client in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (1.3.2)
# Requirement already satisfied: charset-normalizer in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (2.0.12)
# Requirement already satisfied: torchmetrics in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.8.0)
# Requirement already satisfied: docker in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (5.0.3)
# Requirement already satisfied: distro in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (1.7.0)
# Requirement already satisfied: typing in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (3.7.4.3)
# Requirement already satisfied: arrow in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (1.2.2)
# Requirement already satisfied: docstring-parser in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.8.1)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from torchrec-nightly) (2.6)
# Requirement already satisfied: urllib3 in /usr/lib/python3/dist-packages (from torchrec-nightly) (1.22)
# Requirement already satisfied: mypy-extensions in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.4.3)
# Requirement already satisfied: packaging in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (21.3)
# Requirement already satisfied: pyarrow in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (7.0.0)
# Requirement already satisfied: scikit-build in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (0.14.1)
# Requirement already satisfied: numpy in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (1.21.6)
# Requirement already satisfied: attrs in ./.local/lib/python3.7/site-packages (from torchrec-nightly) (21.4.0)
# Requirement already satisfied: wheel>=0.29.0 in /usr/lib/python3/dist-packages (from scikit-build->torchrec-nightly) (0.30.0)
# Requirement already satisfied: setuptools>=28.0.0 in /usr/lib/python3/dist-packages (from scikit-build->torchrec-nightly) (39.0.1)
# Requirement already satisfied: torch>=1.3.1 in ./.local/lib/python3.7/site-packages (from torchmetrics->torchrec-nightly) (1.11.0)
# Requirement already satisfied: importlib-metadata in ./.local/lib/python3.7/site-packages (from torchx-nightly->torchrec-nightly) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in ./.local/lib/python3.7/site-packages (from importlib-metadata->torchx-nightly->torchrec-nightly) (3.8.0)

# %%
# !pip3 install multiprocess
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 KB 3.7 MB/s eta 0:00:00
# Collecting dill>=0.3.4
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 KB 4.4 MB/s eta 0:00:00
# Installing collected packages: dill, multiprocess
# Successfully installed dill-0.3.4 multiprocess-0.70.12.2

# %% [markdown]
# The following steps are needed for the Colab runtime to detect the added shared libraries. The runtime searches for shared libraries in /usr/lib, so we copy over the libraries which were installed in /usr/local/lib/. **This is a very necessary step, only in the colab runtime**.

# %%
# !sudo cp /usr/local/lib/lib* /usr/lib/

# %% [markdown]
# \**Restart your runtime at this point for the newly installed packages to be seen.** Run the step below immediately after restarting so that python knows where to look for packages. **Always run this step after restarting the runtime.**

# %%
import sys
sys.path = ['', '/env/python', '/usr/local/lib/python37.zip', '/usr/local/lib/python3.7', '/usr/local/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/site-packages', './.local/lib/python3.7/site-packages']

# %% [markdown]
# ## **Overview**
# This tutorial will mainly cover the sharding schemes of embedding tables via `EmbeddingPlanner` and `DistributedModelParallel` API and configuring how we would like to shard the tables, as we explore different schemes for embedding tables model parallelism onto multiple GPUs.

# %% [markdown]
# ### Distributed Setup
# Due to the notebook enviroment, we cannot run SPMD program here but we can do multiprocessing inside the notebook to mimic the setup. Users should be responsible for setting up their own SPMD launcher when using Torchrec.
# We setup our environment so that torch distributed based communication backend can work.

# %%
import os
import torch
import torchrec

os.environ["MASTER_ADDR"] = "localhost"
os.environ["MASTER_PORT"] = "29500"

# %% [markdown]
# ### Constructing our embedding model
# Here we use TorchRec offering of [`EmbeddingBagCollection`](https://github.com/facebookresearch/torchrec/blob/main/torchrec/modules/embedding_modules.py#L59) to construct our embedding bag model with embedding tables.
#
# Here, we create an EmbeddingBagCollection (EBC) with four embedding bags. We have two types of tables: large tables and small tables differentiated by their row size difference: 4096 vs 1024. Each table is still represented by 64 dimension embedding.
#
# We configure the `ParameterConstraints` data structure for the tables, which provides hints for the model parallel API to help decide the sharding and placement strategy for the tables.
# In TorchRec, we support
# * `table-wise`: place the entire table on one device;
# * `row-wise`: shard the table evenly by row dimension and place one shard on each device of the communication world;
# * `table-row-wise`: special sharding optimized for intra-host communication for available fast intra-machine device interconnect, e.g. NVLink;
# * `column-wise`: shard the table evenly by embedding dimension, and place one shard on each device of the communication world;
#
# Note how we initially allocate the EBC on device "meta". This will tell EBC to not allocate memory yet.

# %%
from torchrec.distributed.planner.types import ParameterConstraints
from torchrec.distributed.embedding_types import EmbeddingComputeKernel
from torchrec.distributed.types import ShardingType
from typing import Dict

large_table_cnt = 2
small_table_cnt = 2
large_tables=[
  torchrec.EmbeddingBagConfig(
    name="large_table_" + str(i),
    embedding_dim=64,
    num_embeddings=4096,
    feature_names=["large_table_feature_" + str(i)],
    pooling=torchrec.PoolingType.SUM,
  ) for i in range(large_table_cnt)
]
small_tables=[
  torchrec.EmbeddingBagConfig(
    name="small_table_" + str(i),
    embedding_dim=64,
    num_embeddings=1024,
    feature_names=["small_table_feature_" + str(i)],
    pooling=torchrec.PoolingType.SUM,
  ) for i in range(small_table_cnt)
]

def gen_constraints(sharding_type: ShardingType = ShardingType.TABLE_WISE) -> Dict[str, ParameterConstraints]:
  large_table_constraints = {
    "large_table_" + str(i): ParameterConstraints(
      sharding_types=[sharding_type.value],
      compute_kernels=[EmbeddingComputeKernel.BATCHED_FUSED.value],
    ) for i in range(large_table_cnt)
  }
  small_table_constraints = {
    "small_table_" + str(i): ParameterConstraints(
      sharding_types=[sharding_type.value],
      compute_kernels=[EmbeddingComputeKernel.BATCHED_FUSED.value],
    ) for i in range(small_table_cnt)
  }
  constraints = {**large_table_constraints, **small_table_constraints}
  return constraints

# %%
ebc = torchrec.EmbeddingBagCollection(
    device="cuda",
    tables=large_tables + small_tables
)

# %% [markdown]
# ### DistributedModelParallel in multiprocessing
# Now, we have a single process execution function for mimicking one rank's work during SPMD execution.
#
# This code will shard the model collectively with other processes and allocate memories accordingly. It first sets up process groups and do embedding table placement using planner and generate sharded model using `DistributedModelParallel`.

# %%
import torch.nn as nn
def single_rank_execution(
    rank: int,
    world_size: int,
    constraints: Dict[str, ParameterConstraints],
    module: nn.Module,
    backend: str,
) -> None:
  import os
  import torch
  import torch.nn as nn
  import torch.distributed as dist
  from torchrec.distributed.planner import EmbeddingShardingPlanner, Topology
  from torchrec.distributed.embeddingbag import EmbeddingBagCollectionSharder
  from torchrec.distributed.model_parallel import DistributedModelParallel
  from torchrec.distributed.types import ModuleSharder
  from torchrec.distributed.types import ShardingEnv
  from typing import cast

  from typing import Optional
  def init_distributed_single_host(
      rank: int,
      world_size: int,
      backend: str,
      # pyre-fixme[11]: Annotation `ProcessGroup` is not defined as a type.
  ) -> dist.ProcessGroup:
      os.environ["RANK"] = f"{rank}"
      os.environ["WORLD_SIZE"] = f"{world_size}"
      dist.init_process_group(rank=rank, world_size=world_size, backend=backend)
      return dist.group.WORLD
  if backend == "nccl":
      device = torch.device(f"cuda:{rank}")
      torch.cuda.set_device(device)
  else:
      device = torch.device("cpu")
  topology = Topology(world_size=world_size, compute_device="cuda")
  pg = init_distributed_single_host(rank, world_size, backend)
  planner = EmbeddingShardingPlanner(
    topology=topology,
    constraints=constraints,
  )
  sharders= [cast(ModuleSharder[torch.nn.Module], EmbeddingBagCollectionSharder())]
  plan: ShardingPlan = planner.collective_plan(module, sharders, pg)

  sharded_model = DistributedModelParallel(
      module,
      env=ShardingEnv.from_process_group(pg),
      plan=plan,
      sharders=sharders,
      device=device,
  )
  print(f"rank:{rank},sharding plan: {plan}")
  return sharded_model

# %% [markdown]
# ### Multiprocessing Execution
# Now let's execute the code in multi-processes representing multiple GPU ranks.

# %%
import multiprocess
   
def spmd_sharing_simulation(
    sharding_type: ShardingType = ShardingType.TABLE_WISE,
    world_size = 2,
):
  ctx = multiprocess.get_context("forkserver")
  processes = []
  for rank in range(world_size):
      p = ctx.Process(
          target=single_rank_execution,
          args=(
              rank,
              world_size,
              gen_constraints(sharding_type),
              ebc,
              "nccl"
          ),
      )
      p.start()
      processes.append(p)

  for p in processes:
      p.join()
      assert 0 == p.exitcode

# %% [markdown]
# ### Table Wise Sharding
# Now let's execute the code in two processes for 2 GPUs. We can see in the plan print that how our tables are sharded across GPUs. Each node will have one large table and one small which shows our planner tries for load balance for the embedding tables.

# %%
spmd_sharing_simulation(ShardingType.TABLE_WISE)
# Out:
# rank:0,sharding plan: {'': {'large_table_0': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[0], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[4096, 64], placement=rank:0/cuda:0)])), 'large_table_1': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[4096, 64], placement=rank:1/cuda:1)])), 'small_table_0': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[0], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[1024, 64], placement=rank:0/cuda:0)])), 'small_table_1': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[1024, 64], placement=rank:1/cuda:1)]))}}
# rank:1,sharding plan: {'': {'large_table_0': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[0], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[4096, 64], placement=rank:0/cuda:0)])), 'large_table_1': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[4096, 64], placement=rank:1/cuda:1)])), 'small_table_0': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[0], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[1024, 64], placement=rank:0/cuda:0)])), 'small_table_1': ParameterSharding(sharding_type='table_wise', compute_kernel='batched_fused', ranks=[1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[1024, 64], placement=rank:1/cuda:1)]))}}
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py:1403: UserWarning: positional arguments and argument "destination" are deprecated. nn.Module.state_dict will not accept them in the future. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   " and ".join(warn_msg) + " are deprecated. nn.Module.state_dict will not accept them in the future. "
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py:1403: UserWarning: positional arguments and argument "destination" are deprecated. nn.Module.state_dict will not accept them in the future. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   " and ".join(warn_msg) + " are deprecated. nn.Module.state_dict will not accept them in the future. "

# %% [markdown]
# ### Explore other sharding modes
# We have initially explored what table-wise sharding would look like and how it balances the tables placement. Now we explore sharding modes with finer focus on load balance: row-wise.

# %%
spmd_sharing_simulation(ShardingType.ROW_WISE)
# Out:
# rank:1,sharding plan: {'': {'large_table_0': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[2048, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[2048, 0], shard_sizes=[2048, 64], placement=rank:1/cuda:1)])), 'large_table_1': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[2048, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[2048, 0], shard_sizes=[2048, 64], placement=rank:1/cuda:1)])), 'small_table_0': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[512, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[512, 0], shard_sizes=[512, 64], placement=rank:1/cuda:1)])), 'small_table_1': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[512, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[512, 0], shard_sizes=[512, 64], placement=rank:1/cuda:1)]))}}
# rank:0,sharding plan: {'': {'large_table_0': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[2048, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[2048, 0], shard_sizes=[2048, 64], placement=rank:1/cuda:1)])), 'large_table_1': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[2048, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[2048, 0], shard_sizes=[2048, 64], placement=rank:1/cuda:1)])), 'small_table_0': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[512, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[512, 0], shard_sizes=[512, 64], placement=rank:1/cuda:1)])), 'small_table_1': ParameterSharding(sharding_type='row_wise', compute_kernel='batched_fused', ranks=[0, 1], sharding_spec=EnumerableShardingSpec(shards=[ShardMetadata(shard_offsets=[0, 0], shard_sizes=[512, 64], placement=rank:0/cuda:0), ShardMetadata(shard_offsets=[512, 0], shard_sizes=[512, 64], placement=rank:1/cuda:1)]))}}
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py:1403: UserWarning: positional arguments and argument "destination" are deprecated. nn.Module.state_dict will not accept them in the future. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   " and ".join(warn_msg) + " are deprecated. nn.Module.state_dict will not accept them in the future. "
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py:1403: UserWarning: positional arguments and argument "destination" are deprecated. nn.Module.state_dict will not accept them in the future. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   " and ".join(warn_msg) + " are deprecated. nn.Module.state_dict will not accept them in the future. "
